# %%
print("JAI SRIANJENEYAM!!")
# Out:
# JAI SRIANJENEYAM!!

# %%
import pandas as pd

# %%
data=pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService
# 0  7590-VHVEG  Female              0     Yes         No       1           No  \
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection
# 0  No phone service             DSL             No  ...               No  \
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.drop(["customerID"],axis=1,inplace=True)

# %%
data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService
# 0  Female              0     Yes         No       1           No  \
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup
# 0  No phone service             DSL             No          Yes  \
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract
# 0               No          No          No              No  Month-to-month  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
col=data.columns

# %%
col
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# #Target Variable

# %%
data.Churn.value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
sns.set_theme(style="darkgrid",palette='Set1')
ax=sns.countplot(y='Churn',data=data,orient='h')

# %% [markdown]
# #categorical data

# %%
data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService
# 0  Female              0     Yes         No       1           No  \
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup
# 0  No phone service             DSL             No          Yes  \
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract
# 0               No          No          No              No  Month-to-month  \
# ...

# %%
categorical_data=["gender","SeniorCitizen","Partner","Dependents","PhoneService","MultipleLines","InternetService","OnlineSecurity","OnlineBackup","DeviceProtection","TechSupport","StreamingTV","StreamingMovies","Contract","PaperlessBilling","PaymentMethod"]

# %%
for i in categorical_data:
    plt.figure(figsize=(12,6))
    sns.countplot(x=i,data=data)
    plt.title(f"count of {i}")
    plt.show()
    print("""
    
    """)

# %%
fre=data.groupby("SeniorCitizen")["Churn"].value_counts()
fre
# Out:
# SeniorCitizen  Churn
# 0              No       4508
#                Yes      1393
# 1              No        666
#                Yes       476
# Name: count, dtype: int64

# %%
fre=data.groupby("SeniorCitizen")["Churn"].value_counts().to_frame()

# %%
fre
# Out:
#                      count
# SeniorCitizen Churn
# 0             No      4508
#               Yes     1393
# 1             No       666
#               Yes      476

# %%
fre.head()
# Out:
#                      count
# SeniorCitizen Churn
# 0             No      4508
#               Yes     1393
# 1             No       666
#               Yes      476

# %%
fre=data.groupby("SeniorCitizen")["Churn"].value_counts().to_frame()
fre=fre.rename({"count":"NOC"},axis=1).reset_index()

# %%
fre.head()
# Out:
#    SeniorCitizen Churn   NOC
# 0              0    No  4508
# 1              0   Yes  1393
# 2              1    No   666
# 3              1   Yes   476

# %%
fre.inplace=True

# %%
fre.head()
# Out:
#    SeniorCitizen Churn   NOC
# 0              0    No  4508
# 1              0   Yes  1393
# 2              1    No   666
# 3              1   Yes   476

# %%
print(fre["NOC"])
# Out:
# 0    4508
# 1    1393
# 2     666
# 3     476
# Name: NOC, dtype: int64

# %%
fre["Percentage"]=fre["NOC"]/fre["NOC"].sum()*100

# %%
fre.head()
# Out:
#    SeniorCitizen Churn   NOC  Percentage
# 0              0    No  4508   64.006815
# 1              0   Yes  1393   19.778503
# 2              1    No   666    9.456198
# 3              1   Yes   476    6.758484

# %%
senior=fre[fre["SeniorCitizen"]==1]["NOC"]

# %%
senior
# Out:
# 2    666
# 3    476
# Name: NOC, dtype: int64

# %%
senior=senior/senior.values.sum()
senior*100
# Out:
# 2    58.318739
# 3    41.681261
# Name: NOC, dtype: float64

# %%
fre.head()
# Out:
#    SeniorCitizen Churn   NOC  Percentage
# 0              0    No  4508   64.006815
# 1              0   Yes  1393   19.778503
# 2              1    No   666    9.456198
# 3              1   Yes   476    6.758484

# %%
fre.groupby("SeniorCitizen")["Percentage"].sum()
# Out:
# SeniorCitizen
# 0    83.785319
# 1    16.214681
# Name: Percentage, dtype: float64

# %%
sns.barplot(x="SeniorCitizen",y="Percentage",hue='Churn',data=fre)
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='Percentage'>

# %%
def percent_visual(column):
    p=data.groupby(column)["Churn"].value_counts().to_frame()
    p=p.rename({"count":"NOC"},axis=1).reset_index()
    p["Percentage"]=p["NOC"]/p["NOC"].sum()*100
    sns.barplot(x=column,y="Percentage",hue="Churn",data=p)

# %%
fig, axis=plt.subplots(1, 2, figsize=(12,4))
axis[0].set_title("Has partners")
axis[1].set_title("Has dependents")
y_axis="Percentage"
partner=data.groupby("Partner")["Churn"].value_counts()/len(data)
partner=partner.to_frame().rename({"count":y_axis},axis=1).reset_index()
sns.barplot(x='Partner',y=y_axis,hue="Churn",data=partner,ax=axis[0])
dependents=data.groupby("Dependents")["Churn"].value_counts()/len(data)
dependents=dependents.to_frame().rename({"count":y_axis},axis=1).reset_index()
sns.barplot(x='Dependents',y=y_axis,hue="Churn",data=dependents,ax=axis[1])
# Out:
# <Axes: title={'center': 'Has dependents'}, xlabel='Dependents', ylabel='Percentage'>

# %%
percent_visual("MultipleLines")

# %%
percent_visual("InternetService")

# %%
data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService
# 0  Female              0     Yes         No       1           No  \
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup
# 0  No phone service             DSL             No          Yes  \
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract
# 0               No          No          No              No  Month-to-month  \
# ...

# %%
additional=["OnlineSecurity","OnlineBackup","DeviceProtection","TechSupport","StreamingTV","StreamingMovies"]

# %%
melted=pd.melt(data[data["InternetService"]!='No'][additional]).rename({"value":"Has Services"},axis=1)
melted
# Out:
#               variable Has Services
# 0       OnlineSecurity           No
# 1       OnlineSecurity          Yes
# 2       OnlineSecurity          Yes
# 3       OnlineSecurity          Yes
# 4       OnlineSecurity           No
# ...                ...          ...
# 33097  StreamingMovies          Yes
# 33098  StreamingMovies          Yes
# 33099  StreamingMovies           No
# 33100  StreamingMovies           No
# 33101  StreamingMovies          Yes
#
# [33102 rows x 2 columns]

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=melted,x='variable',hue="Has Services")
plt.xlabel("additional services")
plt.ylabel("no of customers")
# Out:
# Text(0, 0.5, 'no of customers')

# %%
melted=data[(data["InternetService"]!='No') & (data["Churn"]=="Yes")]
melted=pd.melt(melted[additional]).rename({"value":"Has Services"},axis=1)
plt.figure(figsize=(10,4))
sns.countplot(data=melted,x='variable',hue="Has Services")
plt.xlabel("additional services")
plt.ylabel("no of customers")
# Out:
# Text(0, 0.5, 'no of customers')

# %%
data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService
# 0  Female              0     Yes         No       1           No  \
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup
# 0  No phone service             DSL             No          Yes  \
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract
# 0               No          No          No              No  Month-to-month  \
# ...

# %%
percent_visual("Contract")
plt.figure(figsize=(10,4))

# %%
percent_visual("PaymentMethod")
plt.figure(figsize=(10,4))

# %%
percent_visual("gender")

# %%
data["TotalCharges"]=data["TotalCharges"].replace(" ",0).astype('float32')

# %%
def kdeplot(feature):
    plt.figure(figsize=(9,4))
    plt.title('KDE for {}'.format(feature))
    ax0=sns.kdeplot(data[data['Churn']=='No'][feature],label='Churn: No')
    ax1=sns.kdeplot(data[data['Churn']=='Yes'][feature],label='Churn: Yes')
kdeplot('tenure')
kdeplot('MonthlyCharges')
kdeplot('TotalCharges')

# %%
sns.scatterplot(y='tenure',x='MonthlyCharges',data=data,hue='Churn')
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='tenure'>

# %%
sns.scatterplot(y='tenure',x='TotalCharges',data=data,hue='Churn')
# Out:
# <Axes: xlabel='TotalCharges', ylabel='tenure'>

# %%
X=data.drop(["Churn"],axis=1)
y=data['Churn']

# %%
data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService
# 0  Female              0     Yes         No       1           No  \
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup
# 0  No phone service             DSL             No          Yes  \
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract
# 0               No          No          No              No  Month-to-month  \
# ...

# %% [markdown]
# #feature Scaling - Normalizing the numerical features

# %%
from sklearn.preprocessing import MinMaxScaler
mmscale=MinMaxScaler()
X["tenure"]=mmscale.fit_transform(X[["tenure"]])
X["TotalCharges"]=mmscale.fit_transform(X[["TotalCharges"]])
X["MonthlyCharges"]=mmscale.fit_transform(X[["MonthlyCharges"]])

# %%
X.head()
# Out:
#    gender  SeniorCitizen Partner Dependents    tenure PhoneService
# 0  Female              0     Yes         No  0.013889           No  \
# 1    Male              0      No         No  0.472222          Yes
# 2    Male              0      No         No  0.027778          Yes
# 3    Male              0      No         No  0.625000           No
# 4  Female              0      No         No  0.027778          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup
# 0  No phone service             DSL             No          Yes  \
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract
# 0               No          No          No              No  Month-to-month  \
# ...

# %%
X[categorical_data].head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines
# 0  Female              0     Yes         No           No  No phone service  \
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport
# 0             DSL             No          Yes               No          No  \
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
for c in categorical_data:
    encoder.fit(X[c])
    X[c]=encoder.transform(X[c])
    mapping=dict(zip(encoder.classes_,encoder.transform(encoder.classes_)))
    print(c,":",mapping)
# Out:
# gender : {'Female': 0, 'Male': 1}
# SeniorCitizen : {0: 0, 1: 1}
# Partner : {'No': 0, 'Yes': 1}
# Dependents : {'No': 0, 'Yes': 1}
# PhoneService : {'No': 0, 'Yes': 1}
# MultipleLines : {'No': 0, 'No phone service': 1, 'Yes': 2}
# InternetService : {'DSL': 0, 'Fiber optic': 1, 'No': 2}
# OnlineSecurity : {'No': 0, 'No internet service': 1, 'Yes': 2}
# OnlineBackup : {'No': 0, 'No internet service': 1, 'Yes': 2}
# DeviceProtection : {'No': 0, 'No internet service': 1, 'Yes': 2}
# TechSupport : {'No': 0, 'No internet service': 1, 'Yes': 2}
# StreamingTV : {'No': 0, 'No internet service': 1, 'Yes': 2}
# StreamingMovies : {'No': 0, 'No internet service': 1, 'Yes': 2}
# Contract : {'Month-to-month': 0, 'One year': 1, 'Two year': 2}
# PaperlessBilling : {'No': 0, 'Yes': 1}
# PaymentMethod : {'Bank transfer (automatic)': 0, 'Credit card (automatic)': 1, 'Electronic check': 2, 'Mailed check': 3}

# %%
y=encoder.fit_transform(y)
mapping=dict(zip(encoder.classes_,encoder.transform(encoder.classes_)))

# %%
print(mapping)
# Out:
# {'No': 0, 'Yes': 1}

# %%
X.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService
# 0       0              0        1           0  0.013889             0  \
# 1       1              0        0           0  0.472222             1
# 2       1              0        0           0  0.027778             1
# 3       1              0        0           0  0.625000             0
# 4       0              0        0           0  0.027778             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup
# 0              1                0               0             2  \
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract
# 0                 0            0            0                0         0  \
# ...

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 1, 0])

# %%
data.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,stratify=y, random_state=42)

# %%
X_train.shape
# Out:
# (4930, 19)

# %%
y_test.shape
# Out:
# (2113,)

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
select2=SelectKBest(f_classif,k=6)
select2.fit(X_train,y_train)
# Out:
# SelectKBest(k=6)

# %%
X_train.columns[select2.get_support()]
# Out:
# Index(['tenure', 'OnlineSecurity', 'TechSupport', 'Contract',
#        'PaperlessBilling', 'MonthlyCharges'],
#       dtype='object')

# %%
X_train_selected=X_train[X_train.columns[select2.get_support()]]

# %%
X_test_selected=X_test[X_train.columns[select2.get_support()]]

# %% [markdown]
# #modeling

# %%
from sklearn.tree import DecisionTreeClassifier
model1=DecisionTreeClassifier()
model1.fit(X_train_selected,y_train)
ans1=model1.predict(X_test_selected)

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,ans1)
score*100
# Out:
# 73.26076668244202

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,ans1)
sns.heatmap(cm,annot=True,fmt='g')
# Out:
# <Axes: >

# %%
from sklearn.ensemble import RandomForestClassifier
model2=RandomForestClassifier()
model2.fit(X_train_selected,y_train)
ans2=model2.predict(X_test_selected)

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,ans2)
score*100
# Out:
# 76.05300520586843

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,ans2)
sns.heatmap(cm,annot=True,fmt='g')
# Out:
# <Axes: >

# %%
from sklearn.svm import SVC
model3=SVC()
model3.fit(X_train_selected,y_train)
ans3=model3.predict(X_test_selected)

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,ans3)
score*100
# Out:
# 79.08187411263606

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,ans3)
sns.heatmap(cm,annot=True,fmt='g')
# Out:
# <Axes: >

# %%
from xgboost import XGBClassifier
model4=XGBClassifier()
model4.fit(X_train_selected,y_train)
ans4=model4.predict(X_test_selected)

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,ans4)
score*100
# Out:
# 77.33080927591102

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,ans4)
sns.heatmap(cm,annot=True,fmt='g')
# Out:
# <Axes: >

# %% [markdown]
# #Building a Predictive System

# %% [raw]
# gender : {'Female': 0, 'Male': 1}
# SeniorCitizen : {0: 0, 1: 1}
# Partner : {'No': 0, 'Yes': 1}
# Dependents : {'No': 0, 'Yes': 1}
# PhoneService : {'No': 0, 'Yes': 1}
# MultipleLines : {'No': 0, 'No phone service': 1, 'Yes': 2}
# InternetService : {'DSL': 0, 'Fiber optic': 1, 'No': 2}
# OnlineSecurity : {'No': 0, 'No internet service': 1, 'Yes': 2}
# OnlineBackup : {'No': 0, 'No internet service': 1, 'Yes': 2}
# DeviceProtection : {'No': 0, 'No internet service': 1, 'Yes': 2}
# TechSupport : {'No': 0, 'No internet service': 1, 'Yes': 2}
# StreamingTV : {'No': 0, 'No internet service': 1, 'Yes': 2}
# StreamingMovies : {'No': 0, 'No internet service': 1, 'Yes': 2}
# Contract : {'Month-to-month': 0, 'One year': 1, 'Two year': 2}
# PaperlessBilling : {'No': 0, 'Yes': 1}
# PaymentMethod : {'Bank transfer (automatic)': 0, 'Credit card (automatic)': 1, 'Electronic check': 2, 'Mailed check': 3}

# %%
feature=['tenure', 'OnlineSecurity', 'TechSupport', 'Contract',
       'PaperlessBilling', 'MonthlyCharges']

# %%
inputs=[]
for i in range(len(feature)):
    
    f=int(input("enter the value: "))
    inputs.append(f)
# Out:
# enter the value: 8
# enter the value: 2
# enter the value: 2
# enter the value: 1
# enter the value: 1
# enter the value: 0

# %%
import numpy as np
i_array=np.array(inputs)
i_array=i_array.reshape(1,-1)
answer=model3.predict(i_array)
print(answer)
if answer[0]==0:
    print("Chances of Churn: N0")
else:
    print("Chances of Churn: Yes")
# Out:
# [0]
# Chances of Churn: N0
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Changing training size

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,stratify=y, random_state=42)
